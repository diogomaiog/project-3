# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import re

# %%
url = "https://www.imovirtual.com/comprar/lisboa/"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)
#soup.prettify

# %%
list_of_site_pages = []
url = 'https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72'
for number in range(2,168):
    list_of_site_pages.append(url+'?page='+str(number))
list_of_site_pages.insert(0,url)
#list_of_site_pages

# %%
URLs = []
prices = []
house_type = []
area = []
locations = []
conditions = []
valid_conditions = ['Usado', 'Renovado', 'Novo','Em construção']

for page in list_of_site_pages:
    print(page)
    response = requests.get(page)
    soup = BeautifulSoup(response.content)

    # returns list of all articles/houses in the current page
    # had to use regex because the class name is different for each article
    listings = soup.find_all(attrs = {'class' : re.compile('(offer-item ad_id)')})

    URLs.append([house.a['href'] for house in listings])
    prices.append([house.find_all(attrs = {'class' : 'offer-item-price'})[0].text.replace(" ","").replace(",","").split("\n")[1].replace("€","") for house in listings])
    house_type.append([house.find_all(attrs = {'class': 'offer-item-rooms hidden-xs'})[0].text for house in listings])
    area.append([float(house.find_all(attrs = {'class': 'hidden-xs offer-item-area'})[0].text.replace(" m²","").replace(",",".").replace(" ","")) for house in listings])
    locations.append([house.find_all(attrs = {'class': 'text-nowrap'})[1].text.split(" ")[-2].replace(",","") for house in listings])
    
    # the condition of the house can be found in two distinct classes, some properties have one type of formatting, others another
    # had to use a try, except to handle both cases
#    i = 0
    for listing in listings:
#        url = listing.a['href']
        try:
            table = listing.find_all(attrs = {'class' : 'parameters-view hidden-xs'})[0]
            condition = [line.text for line in table.find_all('li')][-1]    
            if condition in valid_conditions:
                conditions.append(condition)
#                print(f'Listing {i}, condition: {condition}, {url}')
#                i += 1
            else:
                conditions.append(None)
#                print(f'Listing {i}, condition: {None}, {url}')
#                i += 1
        except:
            try:
                table = listing.find_all(attrs = {'class' : 'params-small clearfix hidden-xs'})[0]
                condition = [line.text for line in table.find_all('li')][-2]
                if condition in valid_conditions:
                    conditions.append(condition)
#                    print(f'Listing {i}, condition: {condition}, {url}')
#                    i += 1
                else:
                    conditions.append(None)
#                    print(f'Listing {i}, condition: {None}, {url}')
#                    i += 1            
            except:
                conditions.append(None)
#                print(f'Listing {i}, condition: {None}, {url}')
#                i += 1
# Out:
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=2
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=3
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=4
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=5
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=152
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=153
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=154
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=155
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=156
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=157
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=158
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=159
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=160
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=161
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=162
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=163
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=164
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=165
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=166
# https://www.imovirtual.com/comprar/apartamento/lisboa/?search%5Bregion_id%5D=11&search%5Bsubregion_id%5D=153&nrAdsPerPage=72?page=167

# %%
master = pd.DataFrame()
master['location'] = [item for lister in locations for item in lister]
master['price'] = [item for lister in prices for item in lister]
master['tier'] = [item for lister in house_type for item in lister]
master['size'] = [item for lister in area for item in lister]
master['link'] = [item for lister in URLs for item in lister]
master['condition'] = conditions

master.head(20)
try:
    master.to_csv('master.csv')
    print('Master table saved.')
except:
    print('Master failed to save.')

# %%
master = master[~master["price"].str.startswith("P")]

# %%
master.head(50)
# Out:
#         location    price tier    size  \
# 0         Lumiar   458500   T2  120.00
# 1          Belém  1680000   T3  159.60
# 2         Nações   409000   T2   85.00
# 3       Alvalade   495000   T2   69.00
# 4        Estrela   315000   T1   62.00
# 5        António   215000   T1   36.00
# 6   Misericórdia   290000   T2   52.00
# 7          Belém   325000   T1   51.00
# 25  https://www.imovirtual.com/anuncio/oportunidad...          Usado
# 26  https://www.imovirtual.com/anuncio/t3-restelo-...       Renovado
# 27  https://www.imovirtual.com/anuncio/t1-1-remode...          Usado
# 28  https://www.imovirtual.com/anuncio/t3-1-com-ac...           None
# 29  https://www.imovirtual.com/anuncio/apartamento...          Usado
# 30  https://www.imovirtual.com/anuncio/alto-dos-mo...  Em construção
# 31  https://www.imovirtual.com/anuncio/apartamento...           Novo
# 32  https://www.imovirtual.com/anuncio/espacoso-e-...          Usado
# 33  https://www.imovirtual.com/anuncio/elegante-t3...       Renovado
# 34  https://www.imovirtual.com/anuncio/apartamento...          Usado
# 35  https://www.imovirtual.com/anuncio/apartamento...       Renovado
# 36  https://www.imovirtual.com/anuncio/apartamento...           None
# 37  https://www.imovirtual.com/anuncio/apartamento...       Renovado
# 38  https://www.imovirtual.com/anuncio/apartamento...          Usado
# 39  https://www.imovirtual.com/anuncio/apartamento...          Usado
# 40  https://www.imovirtual.com/anuncio/apartamento...          Usado
# 41  https://www.imovirtual.com/anuncio/apartamento...           Novo
# 42  https://www.imovirtual.com/anuncio/apartamento...       Renovado
# 43  https://www.imovirtual.com/anuncio/charmoso-ap...          Usado
# 44  https://www.imovirtual.com/anuncio/t2-santa-ma...          Usado
# 45  https://www.imovirtual.com/anuncio/t2-novo-con...           Novo
# 46  https://www.imovirtual.com/anuncio/novo-aparta...           Novo
# 47  https://www.imovirtual.com/anuncio/apartamento...       Renovado
# 48  https://www.imovirtual.com/anuncio/t3-com-rend...       Renovado
# 49  https://www.imovirtual.com/anuncio/apartamento...          Usado

# %%
master[master["price"].str.startswith("P")]
# Out:
# Empty DataFrame
# Columns: [location, price, tier, size, link, condition]
# Index: []

# %%
master.isnull().sum()
# Out:
# location        0
# price           0
# tier            0
# size            0
# link            0
# condition    1169
# dtype: int64

# %%
master.shape
# Out:
# (12024, 6)

# %%
master["price"] = pd.to_numeric(master["price"])

# %%
master
# Out:
#        location    price tier   size  \
# 0        Lumiar   458500   T2  120.0
# 1         Belém  1680000   T3  159.6
# 2        Nações   409000   T2   85.0
# 3      Alvalade   495000   T2   69.0
# 4       Estrela   315000   T1   62.0
# ...         ...      ...  ...    ...
# 12019   Estrela  1100000   T4  180.0
# 12020     Novas   695000   T3  114.0
# 12021   Arroios   249900   T2   55.0
# 12022   António   830000   T4  146.0
# 12023    Nações  1350000   T3  179.0
#
#                                                     link      condition
# 0      https://www.imovirtual.com/anuncio/apartamento...          Usado
# 1      https://www.imovirtual.com/anuncio/t3-belem-li...  Em construção
# 2      https://www.imovirtual.com/anuncio/parque-naco...          Usado
# 3      https://www.imovirtual.com/anuncio/apartamento...       Renovado
# 4      https://www.imovirtual.com/anuncio/apartamento...       Renovado
# ...                                                  ...            ...
# 12019  https://www.imovirtual.com/anuncio/apartamento...          Usado
# 12020  https://www.imovirtual.com/anuncio/apartamento...       Renovado
# 12021  https://www.imovirtual.com/anuncio/t2-arroios-...  Em construção
# 12022  https://www.imovirtual.com/anuncio/t4-para-ven...       Renovado
# 12023  https://www.imovirtual.com/anuncio/t3-duplex-f...          Usado
#
# [12024 rows x 6 columns]

# %%
master.dtypes
# Out:
# location      object
# price          int64
# tier          object
# size         float64
# link          object
# condition     object
# dtype: object

# %%
bin_names = ['xx_small','x_small','small','medium','large','x_large','xx_large','xxx_large']
master
master['size_bins'] = pd.cut(master['size'],8,labels = bin_names)

# %%
master
grouped = master.groupby(['location','size_bins','tier']).agg({"price":'mean'}).reset_index()
grouped.head()
# Out:
#   location size_bins tier     price
# 0    Ajuda  xx_small   T0       NaN
# 1    Ajuda  xx_small   T1       NaN
# 2    Ajuda  xx_small   T2       NaN
# 3    Ajuda  xx_small   T3  340000.0
# 4    Ajuda  xx_small   T4       NaN

# %%
new_df = pd.merge(master, grouped,  how='inner', left_on=['location','size_bins','tier'], right_on = ['location','size_bins','tier'])
new_df.head(20)
# Out:
#    location  price_x tier   size  \
# 0    Lumiar   458500   T2  120.0
# 1    Lumiar   458500   T2  120.0
# 2    Lumiar   458500   T2  120.0
# 3    Lumiar   458500   T2  120.0
# 4    Lumiar   458500   T2  120.0
# 5    Lumiar   458500   T2  120.0
# 6    Lumiar   458500   T2  120.0
# 7    Lumiar   458500   T2  120.0
# 8    Lumiar   458500   T2  120.0
# 9    Lumiar   458500   T2  120.0
# 10   Lumiar   458500   T2  120.0
# 11   Lumiar   458500   T2  120.0
# 12   Lumiar   458500   T2  120.0
# 13   Lumiar   458500   T2  120.0
# 14   Lumiar   458500   T2  120.0
# 15   Lumiar   458500   T2  120.0
# 16   Lumiar   458500   T2  120.0
# 17   Lumiar   458500   T2  120.0
# 18   Lumiar   458500   T2  120.0
# 19   Lumiar   458500   T2  120.0
#
#                                                  link condition size_bins  \
# 0   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 1   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 2   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 3   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 4   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 5   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 6   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 7   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 8   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 9   https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 10  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 11  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 12  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 13  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 14  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 15  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 16  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 17  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 18  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
# 19  https://www.imovirtual.com/anuncio/apartamento...     Usado     small
#
#      price_y
# 0   458500.0
# 1   458500.0
# 2   458500.0
# 3   458500.0
# 4   458500.0
# 5   458500.0
# 6   458500.0
# 7   458500.0
# 8   458500.0
# 9   458500.0
# 10  458500.0
# 11  458500.0
# 12  458500.0
# 13  458500.0
# 14  458500.0
# 15  458500.0
# 16  458500.0
# 17  458500.0
# 18  458500.0
# 19  458500.0

# %%
useful_df = new_df[['link','location','size_bins','tier','price_x','price_y']]

# %%
useful_df.rename(columns = {'price_x':'price','price_y':'average_price'}, inplace = True)
useful_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                                 link location size_bins tier  \
# 0  https://www.imovirtual.com/anuncio/apartamento...   Lumiar     small   T2
# 1  https://www.imovirtual.com/anuncio/apartamento...   Lumiar     small   T2
# 2  https://www.imovirtual.com/anuncio/apartamento...   Lumiar     small   T2
# 3  https://www.imovirtual.com/anuncio/apartamento...   Lumiar     small   T2
# 4  https://www.imovirtual.com/anuncio/apartamento...   Lumiar     small   T2
#
#     price  average_price
# 0  458500       458500.0
# 1  458500       458500.0
# 2  458500       458500.0
# 3  458500       458500.0
# 4  458500       458500.0

# %%
useful_df['profitability'] = useful_df['average_price']-useful_df['price']
useful_df = useful_df.sort_values(by = ['profitability'],ascending = False)
useful_df.head()
# Out:
# <ipython-input-21-72bf301cd6e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   useful_df['profitability'] = useful_df['average_price']-useful_df['price']
#                                                   link location size_bins  \
# 250  https://www.imovirtual.com/anuncio/t3-restelo-...    Belém    medium
# 314  https://www.imovirtual.com/anuncio/t3-restelo-...    Belém    medium
# 330  https://www.imovirtual.com/anuncio/t3-restelo-...    Belém    medium
# 328  https://www.imovirtual.com/anuncio/t3-restelo-...    Belém    medium
# 326  https://www.imovirtual.com/anuncio/t3-restelo-...    Belém    medium
#
#     tier   price  average_price  profitability
# 250   T3  525000      1102500.0       577500.0
# 314   T3  525000      1102500.0       577500.0
# 330   T3  525000      1102500.0       577500.0
# 328   T3  525000      1102500.0       577500.0
# 326   T3  525000      1102500.0       577500.0

# %%
useful_df['link'][1585]
# Out:
# 'https://www.imovirtual.com/anuncio/t2-renovado-em-aguas-furtadas-no-chiado-ID13TXJ.html#10f82a59f2'

# %%
dict_of_size = {'very_small':'below x',
                'small':'below y',
                'medium':'below z',
                'large':'below r',
                'very_large':'below t'}
def searcher():
    x = input('By which category would you like to search? Please enter one of the following: (location, size, tier)').lower()
#x = input('By which category would you like to search? Please enter one of the following: (location, size, tier)').lower()
    if x == 'location':
        #loc = input('Please enter the Province in Lisbon you would like to view').lower()
        #try:
        return useful_df[useful_df['location'] == str(input('Please enter the Province in Lisbon you would like to view').lower())].head(10)
        #except:
        #    print('Are you sure you spelled that right? Make sure you are entering a valid Lisbon Province')
        #    break
    elif x == 'size':
        #siz = input(f'Please enter what size of house you would like to view from the selection: {dict_of_size}').lower()
        #try:
        return useful_df[useful_df['size_bins']  == input(f'Please enter what size of house you would like to view from the selection: {dict_of_size}').lower() ].head(10)
        #except:
        #    print('Are you sure you entered the correct keyword? Make sure you are entering one of the printed options.')
        #    break
    elif x == 'tier':
        #tier = input('Please enter the tier number from 1-10').lower()
        #try:
        return useful_df[useful_df['tier']  == 'T'+str(input('Please enter the tier number from 1-10').lower())].head(10)
        #except:
        #    print('Are you sure you entered the correct keyword? Make sure you are entering one of the printed options.')
        #    break
    else:
        print('Please enter one of the specified options')
searcher()
