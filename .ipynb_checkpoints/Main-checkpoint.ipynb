# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver

# %%
url = "https://www.idealista.pt/en/comprar-casas/lisboa/"


headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [403]>

# %%
url = 'https://www.idealista.pt/en/comprar-casas/lisboa/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
print(result.content.decode())
# Out:
# <html><head><title>idealista.pt</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script>var dd={'cid':'AHrlqAAAAAMAz7QDOi8-jiYA1R4CuQ==','hsh':'AC81AADC3279CA4C7B968B717FBB30','t':'fe','s':17156,'host':'geo.captcha-delivery.com'}</script><script src="https://ct.captcha-delivery.com/c.js"></script></body></html>

# %%
soup = BeautifulSoup(response.content)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <html><head><title>idealista.pt</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script>var dd={'cid':'AHrlqAAAAAMAy3gfK3Z66BkA1R4CuQ==','hsh':'AC81AADC3279CA4C7B968B717FBB30','t':'fe','s':17156,'host':'geo.captcha-delivery.com'}</script><script src="https://ct.captcha-delivery.com/c.js"></script></body></html>
# >

# %%
# this will try to simulate an user agent with java script capabilities
# for this to work you need firefox installed and open
# you also need to change the executable path to match the path of your selenium intallation, and you need to download and place the geckodriver.exe in the folder
# checkout this answer: https://stackoverflow.com/questions/40208051/selenium-using-python-geckodriver-executable-needs-to-be-in-path 

driver = webdriver.Firefox(executable_path=r'C:\ProgramData\Anaconda3\Lib\site-packages\selenium\webdriver\geckodriver.exe')
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <html data-userauth="false" env="pt" lang="en" username=""><!--<![endif]--><head> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <title>Property for sale in Lisbon, Portugal: houses and flats — idealista</title> <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <meta content="18,745 houses and flats for sale in Lisbon, Portugal, from 40,000 euros. Property in Lisbon for sale direct from owners and real estate agents." name="description"/> <meta content="idealista.com" name="author"/> <meta content="on" http-equiv="cleartype"/> <meta content="no-cache" name="pragma"/> <meta content="no-cache" http-equiv="Pragma"/> <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/> <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/> <link href="https://st1.idealista.pt/favicon.ico?20201023-1127" rel="shortcut icon"/> <link href="https://st1.idealista.pt/static/common/icons/32x32.png?20201023-1127" rel="apple-touch-icon" sizes="32x32"/> <link href="https://st1.idealista.pt/static/common/icons/32x32.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/57x57.png?20201023-1127" rel="apple-touch-icon" sizes="57x57"/> <link href="https://st1.idealista.pt/static/common/icons/57x57.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/60x60.png?20201023-1127" rel="apple-touch-icon"/> <link href="https://st1.idealista.pt/static/common/icons/60x60.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/76x76.png?20201023-1127" rel="apple-touch-icon" sizes="76x76"/> <link href="https://st1.idealista.pt/static/common/icons/76x76.png?20201023-1127" rel="apple-touch-icon-precomposed" sizes="76x76"/> <link href="https://st1.idealista.pt/static/common/icons/96x96.png?20201023-1127" rel="apple-touch-icon" sizes="96x96"/> <link href="https://st1.idealista.pt/static/common/icons/96x96.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/120x120.png?20201023-1127" rel="apple-touch-icon" sizes="120x120"/> <link href="https://st1.idealista.pt/static/common/icons/120x120.png?20201023-1127" rel="apple-touch-icon-precomposed" sizes="120x120"/> <link href="https://st1.idealista.pt/static/common/icons/128x128.png?20201023-1127" rel="apple-touch-icon" sizes="128x128"/> <link href="https://st1.idealista.pt/static/common/icons/128x128.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/144x144.png?20201023-1127" rel="apple-touch-icon" sizes="144x144"/> <link href="https://st1.idealista.pt/static/common/icons/144x144.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/152x152.png?20201023-1127" rel="apple-touch-icon" sizes="152x152"/> <link href="https://st1.idealista.pt/static/common/icons/152x152.png?20201023-1127" rel="apple-touch-icon-precomposed" sizes="152x152"/> <link href="https://st1.idealista.pt/static/common/icons/167x167.png?20201023-1127" rel="apple-touch-icon" sizes="167x167"/> <link href="https://st1.idealista.pt/static/common/icons/167x167.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/180x180.png?20201023-1127" rel="apple-touch-icon" sizes="180x180"/> <link href="https://st1.idealista.pt/static/common/icons/180x180.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/192x192.png?20201023-1127" rel="apple-touch-icon" sizes="192x192"/> <link href="https://st1.idealista.pt/static/common/icons/192x192.png?20201023-1127" rel="apple-touch-icon-precomposed"/> <link href="https://st1.idealista.pt/static/common/icons/195x195.png?20201023-1127" rel="apple-touch-icon" sizes="195x195"/ ...
#                         var sas = sas || {};
#                         sas.cmd = sas.cmd || [];
#                         sas.cmd.push(function() {
#                             sas.setup({domain: '//smart.idealista.pt', async: true, renderMode: 2});
#                         });
#                     </script> <script id="advertisementScript">
#                         sas.cmd.push(function() {
#                             sas.call('onecall', {
#                                 siteId:	33116,
#                                 pageId:	376599,
#                                 formatId: '22532,22535',
#                                 target: 'typ=hs;auth=f;geoc=0-EU-PT-11-06;ope=s;geo=0-EU-PT-11-06-XX-XX-XX-XX-XX-XX;geop=0-EU-PT-11'
#                             }, {
#                                 onNoad: function(data){
#                                     if (data.formatId) {
#                                         var bannerDiv = document.getElementById('banners_' + data.formatId);
#                                         if (bannerDiv != null) {
#                                             bannerDiv.style.display = 'none';
#                                         }
#                                     }
#                                 }
#                             });
#                         });
#                     </script> <link href="https://www.idealista.pt/comprar-casas/lisboa/" hreflang="pt" rel="alternate"/><link href="https://www.idealista.pt/es/comprar-casas/lisboa/" hreflang="es" rel="alternate"/><link href="https://www.idealista.pt/fr/comprar-casas/lisboa/" hreflang="fr" rel="alternate"/><link href="https://www.idealista.pt/de/comprar-casas/lisboa/" hreflang="de" rel="alternate"/><link href="https://www.idealista.pt/it/comprar-casas/lisboa/" hreflang="it" rel="alternate"/><link href="https://www.idealista.pt/da/comprar-casas/lisboa/" hreflang="da" rel="alternate"/><link href="https://www.idealista.pt/fi/comprar-casas/lisboa/" hreflang="fi" rel="alternate"/><link href="https://www.idealista.pt/no/comprar-casas/lisboa/" hreflang="no" rel="alternate"/><link href="https://www.idealista.pt/nl/comprar-casas/lisboa/" hreflang="nl" rel="alternate"/><link href="https://www.idealista.pt/pl/comprar-casas/lisboa/" hreflang="pl" rel="alternate"/><link href="https://www.idealista.pt/ro/comprar-casas/lisboa/" hreflang="ro" rel="alternate"/><link href="https://www.idealista.pt/ru/comprar-casas/lisboa/" hreflang="ru" rel="alternate"/><link href="https://www.idealista.pt/sv/comprar-casas/lisboa/" hreflang="sv" rel="alternate"/><link href="https://www.idealista.pt/el/comprar-casas/lisboa/" hreflang="el" rel="alternate"/><link href="https://www.idealista.pt/zh/comprar-casas/lisboa/" hreflang="zh" rel="alternate"/> <link href="/en/comprar-casas/lisboa/" rel="next"/> <script async="" id="sas_script1" src="//smart.idealista.pt/ac?nwid=0&amp;siteid=33116&amp;pgid=376599&amp;fmtid=22532,22535&amp;async=1&amp;oc=1&amp;tmstp=9081415185&amp;tgt=typ%3Dhs%3Bauth%3Df%3Bgeoc%3D0-EU-PT-11-06%3Bope%3Ds%3Bgeo%3D0-EU-PT-11-06-XX-XX-XX-XX-XX-XX%3Bgeop%3D0-EU-PT-11&amp;sh=864&amp;sw=1536&amp;pgDomain=https%3A%2F%2Fwww.idealista.pt%2Fen%2Fcomprar-casas%2Flisboa%2F&amp;noadcbk=sas.noad&amp;isLazy=0&amp;isAdRefresh=0" type="text/javascript"></script><script async="" charset="utf-8" id="utag_idealista.pt-portal_202" src="//tags.tiqcdn.com/utag/idealista/pt-portal/prod/utag.202.js?utv=ut4.46.202009231539" type="text/javascript"></script><script async="" charset="utf-8" id="utag_idealista.pt-portal_31" src="//tags.tiqcdn.com/utag/idealista/pt-portal/prod/utag.31.js?utv=ut4.46.202009071224" type="text/javascript"></script><script async="" charset="utf-8" id="utag_idealista.pt-portal_209" src="//tags.tiqcdn.com/utag/idealista/pt-portal/prod/utag.209.js?utv=ut4.46.202009101109" type="text/javascript"></script><script async="" charset="utf-8" id="utag_idealista.pt-portal_140" src="//tags.tiqcdn.com/utag/idealista/pt-portal/prod/utag.140.js?utv=ut4.46.202004061012" type="text/javascript"></script><script async="" charset="utf-8" id="tiqapp" src="//tags.tiqcdn.com/utag/tiqapp/utag.v.js?a=idealista/pt-portal/202010221542&amp;cb=1603884651050" type="text/javascript"></script><script async="true" id="script-610423-1" src="https://ced-ns.sascdn.com/diff/templates/ts/dist/banner/sas-banner-1.2.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://script.hotjar.com/modules.8831d20acac5f9d5fa63.js"></script><style type="text/css">iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}</style></head> <body id=""><div class="" id="id-cookies"><div><p class="cookies">We use our own cookies and third-party cookies to improve our services and show related advertising. By continuing you accept these cookies. Show <a href="/en/info/aviso-legal" title="cookies-policy">cookies policy.</a></p><a class="icon-new icon-close close" href="#" id="cookies-close"></a></div></div> <script type="text/javascript">
# 						<!--
# 						xtnv = document;
# 						xtsd = "https://logs11";
# 						xtsite =  "410875";
# 						xtdmc = ".idealista.pt";
# 						xtn2 = "2";
# 						xtpage = "listado::listado-resultados::www.idealista.pt/en/comprar-casas/lisboa/";
# 						xtdi = "0";
# 						xt_multc = "";
# 						xt_orderid = "";
# 						xt_roimt = "";
# 						xt_an = "anonymous";
# 						xt_ac = "2";
# 						clic = "#clic#";
# 						xt_tags = "[listado_1]";
# 				    if (window.xtparam != null) {
# 				        window.xtparam += "&tag=" + xt_tags;
# 				    } else {
# 				        window.xtparam = "&tag=" + xt_tags;
# 				    };
# 						if (window.xtparam!=null) {
# 							window.xtparam+="&cmd="+xt_orderid+"&an="+xt_an+"&ac="+xt_ac+"&roimt="+xt_roimt+xt_multc;
# 						} else {
# 							window.xtparam="&cmd="+xt_orderid+"&an="+xt_an+"&ac="+xt_ac+"&roimt="+xt_roimt+xt_multc;
# 						};
# 						//-->
# 					</script><script async="" src="https://st1.idealista.pt/static/common/js/ext/xiti/xiti.js" type="text/javascript"></script> <script type="text/javascript">
# 	var utag_data = {"page":{"section":"portal","subSection":"listing","name":"","language":"en","category":"","subCategory":"","subSubCategory":"","template":""},"user":{"status":"2"},"response":{"statusCode":"200","loadBalancer":"web"},"list":{"ads":[{"adId":"30719326","owner":{"type":"2"}},{"adId":"30372121","owner":{"type":"2"}},{"adId":"30288672","owner":{"type":"2"}},{"adId":"30054702","owner":{"type":"2"}},{"adId":"29954542","owner":{"type":"2"}},{"adId":"30643548","owner":{"type":"2"}},{"adId":"30006242","owner":{"type":"2"}},{"adId":"30729588","owner":{"type":"2"}},{"adId":"28759695","owner":{"type":"2"}},{"adId":"30186976","owner":{"type":"2"}},{"adId":"29982863","owner":{"type":"2"}},{"adId":"29982859","owner":{"type":"2"}},{"adId":"30258470","owner":{"type":"2"}},{"adId":"30258467","owner":{"type":"2"}},{"adId":"30750339","owner":{"type":"2"}},{"adId":"30560011","owner":{"type":"2"}},{"adId":"30713481","owner":{"type":"2"}},{"adId":"30652228","owner":{"type":"2"}},{"adId":"30202649","owner":{"type":"2"}},{"adId":"30595551","owner":{"type":"2"}},{"adId":"30286628","owner":{"type":"2"}},{"adId":"30286737","owner":{"type":"2"}},{"adId":"30286691","owner":{"type":"2"}},{"adId":"30802191","owner":{"type":"2"}},{"adId":"30776307","owner":{"type":"2"}},{"adId":"30764996","owner":{"type":"2"}},{"adId":"30750742","owner":{"type":"2"}},{"adId":"30760238","owner":{"type":"2"}},{"adId":"30686667","owner":{"type":"2"}},{"adId":"30199623","owner":{"type":"2"}}],"resultPageNumber":"30","totalResult":"18745"},"search":{"operation":"1","typology":"1","geo":{"type":"OFFICIAL_ZONE","locationId":"0-EU-PT-11-06","locationLevel":"4"},"orderBy":"relevance-desc"},"markup":{"xtPage":"listado::listado-resultados::www.idealista.pt/en/comprar-casas/lisboa/"},"correlation":{"id":"5d18b2f2-2f43-485a-b9c4-52333dfa3313","session":"a72f7784-3cc5-4359-a5a2-72bdc707d422"}};
# 	var dataLayerContext = utag_data;
# 	var toggleTealiumClicks = true
# </script> <script type="text/javascript">
#     (function(a,b,c,d){
#         a='//tags.tiqcdn.com/utag/idealista/pt-portal/prod/utag.js';
#         b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
#         a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#     })();
# </script> <script async="true" src="https://st1.idealista.pt/static/common/js/criteo/ld.js?20201023-1127" type="text/javascript"></script> <script type="text/javascript">
# 							window.criteo_q = window.criteo_q || [];
# 							window.criteo_q.push(
# 								{ event: "setAccount", account: [13364, 19091] },
# 								{ event: "setCustomerId", id: "" },
# 								{ event: "setSiteType", type: "d" },
# 								{ event: "viewList", item: ["30719326","30372121","30288672"], keywords: "18,745 properties for sale   in Lisbon, Portugal: houses and flats", user_segment: "1" }
# 							);
# 						</script> <header class="help-center ide-header" id="main-header"> <div class="col-ide-lg-12 col-ide-xl-12 content"> <figure class="logo-container"> <a class="id-logo" href="/en/"> <img alt="idealista" src="https://st1.idealista.pt/static/common/img/idealista.svg" title="idealista"/></a> </figure> <nav> <div class="lang-selector lang-responsive"> <span class="lang-selector--lang-selected icon-arrow-dropdown"> <span class="flag lang-en"></span> <span class="lang-text">English</span> </span> <ul class="lang-selector--lang-options" data-url-attribute="/user/update-user-language" data-user-authenticated="false"> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::pt" href="/comprar-casas/lisboa/" id="idioma-pt" rel="nofollow" value="pt"> <span> <span class="flag lang-pt"></span>Português </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::es" href="/es/comprar-casas/lisboa/" id="idioma-es" rel="nofollow" value="es"> <span> <span class="flag lang-es"></span>Español </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::fr" href="/fr/comprar-casas/lisboa/" id="idioma-fr" rel="nofollow" value="fr"> <span> <span class="flag lang-fr"></span>Français </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::de" href="/de/comprar-casas/lisboa/" id="idioma-de" rel="nofollow" value="de"> <span> <span class="flag lang-de"></span>Deutsch </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::it" href="/it/comprar-casas/lisboa/" id="idioma-it" rel="nofollow" value="it"> <span> <span class="flag lang-it"></span>Italiano </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::da" href="/da/comprar-casas/lisboa/" id="idioma-da" rel="nofollow" value="da"> <span> <span class="flag lang-da"></span>Dansk </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::fi" href="/fi/comprar-casas/lisboa/" id="idioma-fi" rel="nofollow" value="fi"> <span> <span class="flag lang-fi"></span>Suomi </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::no" href="/no/comprar-casas/lisboa/" id="idioma-no" rel="nofollow" value="no"> <span> <span class="flag lang-no"></span>Norsk </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::nl" href="/nl/comprar-casas/lisboa/" id="idioma-nl" rel="nofollow" value="nl"> <span> <span class="flag lang-nl"></span>Nederlands </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::pl" href="/pl/comprar-casas/lisboa/" id="idioma-pl" rel="nofollow" value="pl"> <span> <span class="flag lang-pl"></span>Polski </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::ro" href="/ro/comprar-casas/lisboa/" id="idioma-ro" rel="nofollow" value="ro"> <span> <span class="flag lang-ro"></span>Română </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::ru" href="/ru/comprar-casas/lisboa/" id="idioma-ru" rel="nofollow" value="ru"> <span> <span class="flag lang-ru"></span>Русский </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::sv" href="/sv/comprar-casas/lisboa/" id="idioma-sv" rel="nofollow" value="sv"> <span> <span class="flag lang-sv"></span>Svenska </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::el" href="/el/comprar-casas/lisboa/" id="idioma-el" rel="nofollow" value="el"> <span> <span class="flag lang-el"></span>Ελληνικά </span> </a> </li> <li> <a data-click="1" data-markup="cambio::idioma::cabecera::zh" href="/zh/comprar-casas/lisboa/" id="idioma-zh" rel="nofollow" value="zh"> <span> <span class="flag lang-zh"></span>中文 </span> </a> </li> <li class="separator"> <a data-click="1" data-markup="cambio::pais::cabecera::com" href="https://www.idealista.com/en/" title="">idealista.com</a> </li> <li> <a data-click="1" data-markup="cambio::pais::cabecera::it" href="https://www.idealista.it/en/ ...
#                             sas.cmd.push(function() {
#                                 sas.render('22532');
#                             });
#                         </script> </div> </article> <article class="item item_contains_branding item_hightop item-multimedia-container" data-adid="30054702"> <picture class="item-multimedia"> <div class="item-multimedia-features"> <span class="icon-3d-tour"></span> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count="">1/</span><span data-total="">25</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Premium</span> <div class="item-gallery"><div class="mask-wrapper is-clickable"><div class="gallery-arrow left icon-arrow-left" style="visibility: hidden;"></div><div class="gallery-arrow right icon-arrow-right" style="visibility: visible;"></div><div class="mask" style="touch-action: pan-y; user-select: none; transition-duration: 0s; transform: translateX(0px);"><div class="placeholder" style="transform: translateX(-360px);"></div><div class="placeholder" style="transform: translateX(0px);"><img alt="" src="https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/19/a5/b7/132320665.jpg" style="visibility: visible;"/></div><div class="placeholder" style="transform: translateX(360px);"><img alt="" src="https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/1f/e1/e1/132320666.jpg" style="visibility: visible;"/></div></div></div></div> </picture> <div class="item-info-container"> <picture class="logo-branding"> <a data-click="1" data-markup="listado::logo-agencia" href="/en/pro/engel-volkers-lisboa/" title="Engel &amp; Völkers Lisboa"> <img alt="Engel &amp; Völkers Lisboa" data-ondemand-img="https://st3.idealista.pt/c6/2b/2f/engel-volkers-lisboa.gif" src="https://st1.idealista.pt/static/common/img/icons/px.png"/> </a> </picture> <a class="item-link" href="/en/imovel/30054702/" title="T2 flat in Anjos, Arroios">T2 flat in Anjos, Arroios</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">570,000<span class="txt-big">€</span></span> </div> <span class="item-detail">T2 <small></small></span> <span class="item-detail">142 <small>m²</small></span> <div class="item-description description"> <p class="ellipsis"> Beauty, comfort, quality and refinement is what you can find in this 3 bedroom apartment situated in the Bairro das Colónias. Located in... </p> </div> <div class="item-toolbar"> <span class="icon-phone item-not-clickable-phone">215561507</span> <a class="icon-phone phone-btn item-clickable-phone" href="tel:215561507" target="_blank"> <span>Call</span> </a> <button class="icon-chat email-btn action-email fake-anchor"><span>Contact</span></button> <button class="favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Save" data-text-remove="Favourite" title="Save"> <svg class="icon-heart" height="1.5rem" version="1.1" viewbox="0 0 24 24" width="1.5rem" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <title>fav-icon</title> <g fill-rule="evenodd" id="svg-heart" stroke-width="1"> <g id="Group" transform="translate(1.469388, 1.959184)"> <path d="M10.5494545,4.34654416 C13.0317121,-2.66965835 21.0989011,-0.423454109 21.0989011,5.63737113 C21.0989011,12.2223851 10.5494545,20.5714286 10.5494545,20.5714286 C10.5494545,20.5714286 0,12.2223851 0,5.63737113 C0,-0.423454109 8.0671916,-2.66965835 10.5494545,4.34654416 Z" id="fav-svg-path"></path> </g> </g> <g fill-rule="evenodd" id="svg-heart-fill" stroke-width="1"> <g id="Group" transform="translate(1.469388, 1.959184)"> <path d="M10.5494545,4.34654416 C13.0317121,-2.66965835 21.0989011,-0.423454109 21.0989011,5.63737113 C21.0989011,12.2223851 10.5494545,20.5714286 10.5494545,20.5714286 C10.5494545,20.5714286 0,12.2223851 0,5.63737113 C0,-0.423454109 8.0671916,-2.66965835 10.5494545,4.34654416 Z" id="fav-svg-fill"></path> </g> </g> </svg><span>Save</span> </button> </div> </div> </article> <article class="item item_contains_branding item_hightop item-multimedia-container" d ...
# <div class="expert-card compact card-0" data-commercialdataid="440150192">
# <a class="link-wrap" href="/pro/homelovers/comprar-casas/lisboa/" title="HomeLovers">
# <div class="head">
# <div class="expert-multimedia" style="background-color: rgb(209, 4, 21);">
# <div class="image-holder">
# </div>
# </div>
# </div></a><div class="info-container"><a class="link-wrap" href="/pro/homelovers/comprar-casas/lisboa/" title="HomeLovers">
# </a><div class="centrable"><a class="link-wrap" href="/pro/homelovers/comprar-casas/lisboa/" title="HomeLovers">
# <div class="agency-logo">
# <img crossorigin="anonymous" src="https://st3.idealista.pt/fc/50/b1/homelovers.gif"/>
# </div>
# </a><h4 class="agency-link"><a class="link-wrap" href="/pro/homelovers/comprar-casas/lisboa/" title="HomeLovers">
# </a><a class="item-link" href="/pro/homelovers/comprar-casas/lisboa/" title="HomeLovers">HomeLovers</a>
# </h4>
# </div>
# <div class="details">
# <p class="expert-detail centrable">229 properties in this area</p>
# <p class="expert-detail centrable">4 years on idealista</p>
# </div>
# </div>
# </div>
# <div class="expert-card compact card-1" data-commercialdataid="440041375">
# <a class="link-wrap" href="/pro/jll-residential-portugal/comprar-casas/lisboa/" title="JLL Residential Portugal">
# <div class="head">
# <div class="expert-multimedia" style="background-color: rgb(193, 70, 77);">
# <div class="image-holder">
# </div>
# </div>
# </div></a><div class="info-container"><a class="link-wrap" href="/pro/jll-residential-portugal/comprar-casas/lisboa/" title="JLL Residential Portugal">
# </a><div class="centrable"><a class="link-wrap" href="/pro/jll-residential-portugal/comprar-casas/lisboa/" title="JLL Residential Portugal">
# <div class="agency-logo">
# <img crossorigin="anonymous" src="https://st3.idealista.pt/b0/f1/15/jll-residential-portugal.gif"/>
# </div>
# </a><h4 class="agency-link"><a class="link-wrap" href="/pro/jll-residential-portugal/comprar-casas/lisboa/" title="JLL Residential Portugal">
# </a><a class="item-link" href="/pro/jll-residential-portugal/comprar-casas/lisboa/" title="JLL Residential Portugal">JLL Residential Portugal</a>
# </h4>
# </div>
# <div class="details">
# <p class="expert-detail centrable">1057 properties in this area</p>
# <p class="expert-detail centrable">6 years on idealista</p>
# </div>
# </div>
# </div>
# <div class="expert-card compact card-2" data-commercialdataid="440041780">
# <a class="link-wrap" href="/pro/personalmed/comprar-casas/lisboa/" title="Personalmed">
# <div class="head">
# <div class="expert-multimedia" style="background-color: rgb(214, 183, 40);">
# <div class="image-holder">
# </div>
# </div>
# </div></a><div class="info-container"><a class="link-wrap" href="/pro/personalmed/comprar-casas/lisboa/" title="Personalmed">
# </a><div class="centrable"><a class="link-wrap" href="/pro/personalmed/comprar-casas/lisboa/" title="Personalmed">
# <div class="agency-logo">
# <img crossorigin="anonymous" src="https://st3.idealista.pt/89/7e/9b/personalmed.gif"/>
# </div>
# </a><h4 class="agency-link"><a class="link-wrap" href="/pro/personalmed/comprar-casas/lisboa/" title="Personalmed">
# </a><a class="item-link" href="/pro/personalmed/comprar-casas/lisboa/" title="Personalmed">Personalmed</a>
# </h4>
# </div>
# <div class="details">
# <p class="expert-detail centrable">168 properties in this area</p>
# <p class="expert-detail centrable">6 years on idealista</p>
# </div>
# </div>
# </div>
# </div> </div> <a class="more" href="/en/pro/comprar-casas/lisboa/imobiliarias" title="Real estate agents in Lisbon"> Real estate agents in Lisbon </a> </div> <article class="item item_contains_branding item_hightop item-multimedia-container" data-adid="30186976"> <picture class="item-multimedia"> <div class="item-multimedia-features"> <span class="icon-virtual-tour"></span> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count=""></span><span data-total="">30</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Premium</span> <div class="item-gallery"> <picture class="gallery-fallback icon-no-pics"> <img class="vertical" data-ondemand-img="https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/eb/cd/13/131417768.jpg" src="https://st1.idealista.pt/static/common/img/icons/px.png"/> </picture> </div> </picture> <div class="item-info-container"> <picture class="logo-branding"> <a data-click="1" data-markup="listado::logo-agencia" href="/en/pro/engel-volkers-lisboa/" title="Engel &amp; Völkers Lisboa"> <img alt="Engel &amp; Völkers Lisboa" data-ondemand-img="https://st3.idealista.pt/c6/2b/2f/engel-volkers-lisboa.gif" src="https://st1.idealista.pt/static/common/img/icons/px.png"/> </a> </picture> <a class="item-link" href="/en/imovel/30186976/" title="T4 flat in São Domingos de Benfica, Lisboa">T4 flat in São Domingos de Benfica, Lisboa</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">1,095,000<span class="txt-big">€</span></span> </div> <span class="item-detail">T4 <small></small></span> <span class="item-detail">281 <small>m²</small></span> <span class="item-detail">Floor 1 <small> with lift</small></span> <div class="item-description description"> <p class="ellipsis"> Excellent apartment with 4+2 bedrooms and 4 bathrooms. 3 parking spaces and a storage room next to the Hospital dos Lusíadas. Fully renov... </p> <span class="listing-tags"> Luxury </span> </div> <div class="item-toolbar"> <span class="icon-phone item-not-clickable-phone">215561507</span> <a class="icon-phone phone-btn item-clickable-phone" href="tel:215561507" target="_blank"> <span>Call</span> </a> <button class="icon-chat email-btn action-email fake-anchor"><span>Contact</span></button> <button class="favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Save" data-text-remove="Favourite" title="Save"> <svg class="icon-heart" height="1.5rem" version="1.1" viewbox="0 0 24 24" width="1.5rem" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <title>fav-icon</title> <g fill-rule="evenodd" id="svg-heart" stroke-width="1"> <g id="Group" transform="translate(1.469388, 1.959184)"> <path d="M10.5494545,4.34654416 C13.0317121,-2.66965835 21.0989011,-0.423454109 21.0989011,5.63737113 C21.0989011,12.2223851 10.5494545,20.5714286 10.5494545,20.5714286 C10.5494545,20.5714286 0,12.2223851 0,5.63737113 C0,-0.423454109 8.0671916,-2.66965835 10.5494545,4.34654416 Z" id="fav-svg-path"></path> </g> </g> <g fill-rule="evenodd" id="svg-heart-fill" stroke-width="1"> <g id="Group" transform="translate(1.469388, 1.959184)"> <path d="M10.5494545,4.34654416 C13.0317121,-2.66965835 21.0989011,-0.423454109 21.0989011,5.63737113 C21.0989011,12.2223851 10.5494545,20.5714286 10.5494545,20.5714286 C10.5494545,20.5714286 0,12.2223851 0,5.63737113 C0,-0.423454109 8.0671916,-2.66965835 10.5494545,4.34654416 Z" id="fav-svg-fill"></path> </g> </g> </svg><span>Save</span> </button> </div> </div> </article> <article class="item item_contains_branding item_hightop item-multimedia-container" data-adid="29982863"> <picture class="item-multimedia"> <div class="item-multimedia-features"> <span class="icon-video"></span> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count=""></span><span data-total="">39</span> </div> <div cla ...
#                             sas.cmd.push(function() {
#                                 sas.render('22535');
#                             });
#                         </script> </div> </article> <article class="item item_contains_branding item_featured item_hightop item-multimedia-container" data-adid="30286628"> <picture class="item-multimedia"> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count=""></span><span data-total="">40</span> </div> <div class="item-ribbon-container"> <div class="item-ribbon ribbon-on">New homes</div> </div> <span class="item-push-up txt-caption">Premium</span> <div class="item-gallery"> <picture class="gallery-fallback icon-no-pics"> <img class="vertical" data-ondemand-img="https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/70/40/74/130152287.jpg" src="https://st1.idealista.pt/static/common/img/icons/px.png"/> </picture> </div> </picture> <div class="item-info-container"> <picture class="logo-branding"> <a data-click="1" data-markup="listado::logo-agencia" href="/en/pro/kw-select-lisboa/" title="KW Select"> <img alt="KW Select" data-ondemand-img="https://st3.idealista.pt/ec/6f/b2/kw-select-lisboa.gif" src="https://st1.idealista.pt/static/common/img/icons/px.png"/> </a> </picture> <a class="item-link" href="/en/imovel/30286628/" title="T3 flat in praceta R. Andaluz, 38, Saldanha - Picoas, São Jorge de Arroios, Arroios">T3 flat in praceta R. Andaluz, 38, Saldanha - Picoas, São Jorge de Arroios, Arroios</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">1,344,000<span class="txt-big">€</span></span> <span class="item-parking">Garage included</span> </div> <span class="item-detail">T3 <small></small></span> <span class="item-detail">210 <small>m²</small></span> <span class="item-detail">Ground floor <small> with lift</small></span> <div class="item-description description"> <p class="ellipsis"> In the heart of the city, next to Avenida da Liberdade and the renewed Avenida Duque de Loulé, the "Andaluz 38" project develops a privat... </p> <span class="listing-tags"> Luxury </span> </div> <div class="item-toolbar"> <span class="icon-phone item-not-clickable-phone">215550931</span> <a class="icon-phone phone-btn item-clickable-phone" href="tel:215550931" target="_blank"> <span>Call</span> </a> <button class="icon-chat email-btn action-email fake-anchor"><span>Contact</span></button> <button class="favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Save" data-text-remove="Favourite" title="Save"> <svg class="icon-heart" height="1.5rem" version="1.1" viewbox="0 0 24 24" width="1.5rem" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <title>fav-icon</title> <g fill-rule="evenodd" id="svg-heart" stroke-width="1"> <g id="Group" transform="translate(1.469388, 1.959184)"> <path d="M10.5494545,4.34654416 C13.0317121,-2.66965835 21.0989011,-0.423454109 21.0989011,5.63737113 C21.0989011,12.2223851 10.5494545,20.5714286 10.5494545,20.5714286 C10.5494545,20.5714286 0,12.2223851 0,5.63737113 C0,-0.423454109 8.0671916,-2.66965835 10.5494545,4.34654416 Z" id="fav-svg-path"></path> </g> </g> <g fill-rule="evenodd" id="svg-heart-fill" stroke-width="1"> <g id="Group" transform="translate(1.469388, 1.959184)"> <path d="M10.5494545,4.34654416 C13.0317121,-2.66965835 21.0989011,-0.423454109 21.0989011,5.63737113 C21.0989011,12.2223851 10.5494545,20.5714286 10.5494545,20.5714286 C10.5494545,20.5714286 0,12.2223851 0,5.63737113 C0,-0.423454109 8.0671916,-2.66965835 10.5494545,4.34654416 Z" id="fav-svg-fill"></path> </g> </g> </svg><span>Save</span> </button> </div> </div> </article> <article class="item item_contains_branding item_hightop item-multimedia-container" data-adid="30286737"> <picture class="item-multimedia"> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count=""></span><span data-total="">32</span> </div> <div class="item-ribbon-con ...
# 	var smartBannerConfig={activated:true,locale:"en",userAuthenticated:false,urls:{urlLegalNotice:"/en/info/aviso-legal"}};
# </script> <script type="text/javascript">
#
# 	var communicatorConfig={enabled:true,endPointURL:"//commt.idealista.pt",authCookieName:"cc",refreshTokenURL:"/communicator/refresh-token.ajax"};
#
# </script> <script>
# 	var config={locale:"en",userAuthenticated:false,favoriteFirstTime:true,discardFirstTime:true,urlAddFavorite:"/add-favorite.htm",addFavoriteTargetId:"16",discardTargetId:"38",viewFavoritesTargetId:"41",urlRemoveFavorite:"/remove-favorite.htm",urlAddDiscarded:"/add-ruled-out-web-listing.htm",urlRemoveDiscarded:"/remove-ruled-out.htm",urlAddComment:"/update-favorite-comment.htm",urlContact:"/en/ajax/contact/11/sendcontact.ajax",urlListingContact:"/en/ajax/contact/11/sendcontact.ajax",urlGalleryContact:"/en/ajax/contact/37/sendcontact.ajax",urlCounterOffer:"/ajax/contact/suggested/sendcontact.ajax",urlSuggestedAgencies:"/en/ajax/zoneexperts/suggested/11/sendcontact.ajax",urlReloadCaptcha:"/ajax/captcha/reloadCaptcha.ajax",urlAdContactInfo:"/ajax/listingController/adContactInfo.ajax",urlAdNewContactInfo:"/en/ajax/listingController/adContactInfoForListing.ajax",mediaTablet:"screen and (max-width: 1023px) and (min-width: 768px)",mediaMobile:"screen and (max-width: 767px)",mediaDesktop:"screen and (min-width: 1023px)",listAction:"/en/ajax/listingcontroller/listingajax.ajax",typology:"1",typologyName:"home",operation:"1",operationName:"sale",locationUri:"lisboa",urlAddDeferredDiscarded:"/add-deferred-ruled-out.htm",mapSearchUrl:"/en/comprar-casas/lisboa/mapa-google",listingSearchUrl:"/en/comprar-casas/lisboa/",imageSizes:{"1280X400":80,"140X105":80,"140":80,"300":85,"600":80,"850":80,"1500":80,"250X188":80,"500X375":80,"300X225":80,"600X450":80},mapMode:false,showPopupOnClickingDetail:true,saveAlertPopupCookieName:"askToSaveAlertPopUp",urlSearchTotals:"/en/ajax/listingcontroller/totals/listingajax.ajax",searchWithoutFilters:"true",xitiClientMarkup:{listingFavoritesLoginInPlace:"listado::conversiones::login-favoritear-inplace",listingRuledOutLoginInPlace:"listado::conversiones::login-descartar-inplace",listingFavoritesTabLink:"listado::click-a-favoritos",listingGalleryContactButton:"listado::galeria::boton-contactar",listingGalleryLinkDetail:"listado::galeria::enlace-detalle"},maxAdContactMessagesSuggested:3,changeListingType:"/en/ajax/listingcontroller/changeMode.ajax",listingType:"1",urlShapeValidation:"/en/ajax/listingcontroller/validateshape.ajax",liveSearchMapZoom:"",liveSearchMapNorthEast:"",liveSearchMapSouthWest:"",liveSearchListingUrls:"/en/ajax/listingcontroller/livesearchlistingurls.ajax",urlMapLayoutTypeSelection:"/ajax/listingcontroller/layoutselector.ajax",urlValidateShapeAlert:"/ajax/shapealertvalidateerrors",urlCreateUserFilteringFavs:"/new-user-filtering-favs.ajax",expertCardColorFromLogo:true,expertleaveLinkForZeroAgencies:false,expertCardContactAvailable:false,expertCardCompactMode:true,zoneOfInterest:"",micrositeSearchUrl:"",freeTextUrlRetriver:"/ajax/freetexturlretriever.ajax",liveSearchUrlRetriever:"/ajax/livesearchlistingurlretriever.ajax",};var listingMultimediaGallery={"30719326":[{multimediaId:130567187,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/d7/ee/01/130567187.jpg",width:1500,height:1000,tagId:"FACADE"},{multimediaId:130567152,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/a6/76/cc/130567152.jpg",width:1500,height:1000,tagId:"FACADE"},{multimediaId:130567154,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/cf/a6/b2/130567154.jpg",width:1500,height:1000,tagId:"FACADE"},{multimediaId:130567195,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/1f/f5/5c/130567195.jpg",width:1500,height:1000,tagId:"INPUT_OUTPUT"},{multimediaId:130567209,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/ef/8f/ae/130567209.jpg",width:1500,height:1000,tagId:"HALL"},{multimediaId:130567186,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/e9/6b/ab/130567186.jpg",width:1500,height:1000,tagId:"HALL"},{multimediaId:130567156,src:"https://img3.idealista.pt/blur/WEB_LISTING_TOP/0/id.pro.pt.image.master/1f/d4/d9/130567156.jpg",width:1500,height:1000,tagId:"CORRIDOR"}, ...
#
#
#
# </script> <script>
# 	var breadcrumbConfig={breadcrumbAction:"/en/ajax/breadcrumbController/getLastLevelBreadcrumbGeoAjax.ajax",breadcrumbUrlValue:"/en/comprar-casas/lisboa/",breadcrumbUrlAllMunicipalitiesLevel:"",pageDiscriminatorValue:"listing_home.htm"};
# </script> <script defer="" src="https://st1.idealista.pt/static/common/release/listing/listing.js?20201023-1127" type="text/javascript"></script> <script id="login-box-title-fav" type="text/microtemplate">
# 		<span class="icon-fav">
# 			<span class="txt-bold">Save to favourites</span>
# 		</span>
# 	</script> <script id="login-box-title-discard" type="text/microtemplate">
# 		<span class="icon-delete">
# 			<span class="txt-bold">Discard</span>
# 		</span>
# 	</script> <script id="login-box-title-favfilter" type="text/microtemplate">
# 		<span class="txt-bold">See your favourites within this search</span>
# 	</script> <script id="login-box-title-stats" type="text/microtemplate">
# 		<span class="txt-bold">View the number of visits and leads</span>
# 	</script> <script id="login-box-content-text-fav" type="text/microtemplate">
# 		<div class="info-txt save-ad-text">
# 			<p>You can create a list of your favourite listings. We will let you know if they change price, when photos are added, or if they are removed.</p>
# 			<p>You can also add personal notes that are only visible to you to help you remember interesting details.</p>
# 		</div>
# 	</script> <script id="login-box-content-text-discard" type="text/microtemplate">
# 		<div class="info-txt">
# 			<p>Discard the listings that don't interest you and they will stop showing up in your searches</p>
# 			<p>If you change your mind you can retrieve them from your discarded listings</p>
# 		</div>
# 	</script> <script id="login-box-content-text-favfilter" type="text/microtemplate">
# 		<div class="info-txt">
# 			<p>Quickly view your favourites and filter them as you like</p>
# 		</div>
# 	</script> <script id="login-box-content-text-stats" type="text/microtemplate">
# 		<div class="info-txt">
# 			<p>View the popularity data for any listings that interest you: how many visits and leads they have created, and how many people have saved them to their favourites</p>
# 		</div>
# 	</script> <script id="login-box-content-tmpl" type="text/microtemplate">
# 		<div class="login-box-form modal-inner"> {{=contentExplanation}} <div id="loginlicker"> <label for="email"> <span class="username initial"> Your email </span> <span class="username named" style="display:none;" data-username="Hello again :-)"> </span> <input id="email" class="email" type="email" name="email" autocomplete="email"/> <span class="email-feedback">Come on, enter an email address ;-)</span> </label> <p class="spinner-inline left"> Checking email </p> <div class="item-form pass-wrapper"> <label> <span class="username">Your password</span> <input type="password" class="password js-password-field" name="pwd" data-password-show="Show" data-password-hide="Hide"/> <span class="password-feedback">If you don't enter a password, we can't let you in ;-)</span> </label> </div> <p><a href="/en/recordar-palavra-passe" class="forgotpassword">Forgot your password?</a></p> <label class="input-checkbox"> <input name="cookie" type="checkbox" checked="checked"/> <span><span>Remember your details</span></span> </label> <label> <span class="msg-repeat"> Please verify your email is written correctly </span> <span class="repeat"></span> </label> <label> <span id="msg-accept-privacy-policy"> You must accept the privacy policy to continue </span> </label> <label class="input-checkbox"> <input id="privacy-policy" name="privacy-policy" type="checkbox" data-markup-privacy/> <span><span>Accept <a href="https://www.idealista.pt/en/info/protecao-dados" target="_blank">privacy policy</a></span></span> </label> <label class="input-checkbox"> <input id="subscribe-mailing" name="subscribe-mailing" type="checkbox" data-markup-communications/> <span><span>Receive information about properties, news and other promotional communications from idealista, idealista/data, idealista/créditohabitação and Rentalia based on your profile.</span></span> </label> </div> </div>
# 	</script> <script id="login-box-button-initial" type="text/microtemplate">
# 		<div class="modal-inner">
# 			<a href="#" class="btn action longer accept dummy">
# 				Let's go!
# 			</a>
# 		</div>
# 	</script> <script id="login-box-button-fav" type="text/microtemplate">
# 		<div class="modal-inner">
# 			<a href="#" class="btn action longer accept">
# 				Save to favourites
# 			</a>
# 		</div>
# 	</script> <script id="login-box-button-discard" type="text/microtemplate">
# 		<div class="modal-inner">
# 			<a href="#" class="btn action longer accept">
# 				Discard listing
# 			</a>
# 		</div>
# 	</script> <script id="login-box-button-favfilter" type="text/microtemplate">
# 		<div class="modal-inner">
# 			<a href="#" class="btn action longer accept">
# 				Show only favourites
# 			</a>
# 		</div>
# 	</script> <script id="login-box-button-stats" type="text/microtemplate">
# 		<div class="modal-inner">
# 			<a href="#" class="btn action longer accept">
# 				See stats
# 			</a>
# 		</div>
# 	</script> <script id="login-box-feedback-generic-content" type="text/microtemplate">
# 		<p class="feedback warning icon-feedbk-alert">You just need to confrm your email address</p>
# 		<div class="modal-inner">
# 			<p>We've sent an email to {{=email}}. Don't forget to check your spam folder, just in case ;-)</p>
# 		</div>
# 	</script> <script id="login-box-feedback-generic-buttons" type="text/microtemplate">
# 		<div class="modal-inner">
# 			<a href="#" class="btn regular longer accept">
# 				Got it
# 			</a>
# 		</div>
# 	</script> <script id="promo-app-title-tmpl" type="text/microtemplate">
# 	<span class="txt-bold">Download our app</span>
# </script> <script id="promo-app-content-tmpl" type="text/microtemplate">
# 	<img class="promoApp" src="">
# 	<p>Receive instant alerts for your searches and favourites wherever you are with the free idealista app</p>
# 	<div class="download"><a id="buttonDownloadApp" class="btn action txt-bold" data-markup='promo-app::download' href="http://m.onelink.me/5732e69f">Download now</a></div>
# 	<div class="cancel"><a class="buttonCancelDownloadApp" id="buttonCancelDownloadApp" data-markup="promo-app::no-thanks">No thanks</a></div>
# </script> <script async="" defer="" src="https://www.google.com/recaptcha/api.js?render=6LfbRo8UAAAAACP8o7pnNypM36YmkwpV15Xz2dQr"></script> <script>
# var configTwoSteps = {
# 	urls: {
# 		defaultLogin: "/en/login.ajax",
# 		defaultPreauthorized: "/en/login-preauthorized.ajax",
#
#
# 		userStatus: "/check-identification-service-user-status.ajax",
# 		emailVerifyUrl: "/en/ajax/alerts-ls-existence-and-active"
# 	},
# 	userStatus: "", //	authorized, preauthorized, blocked, error
#     recaptchaToggle: false,
#     recaptcha2slToggle: true,
#     recaptcha2slPublicKey: "6LfbRo8UAAAAACP8o7pnNypM36YmkwpV15Xz2dQr",
#     recaptcha2slActionName: "login2sl",
#     recaptchaNotifyIncidence: "notifyIncidence",
# 	deviceInfoToggle: false
# };
# </script> <script>
# var configSendIncidences = {
#     recaptchaPublicKey: "6LfbRo8UAAAAACP8o7pnNypM36YmkwpV15Xz2dQr",
#     recaptchaAction: "notifyIncidence",
# };
# </script> <script>
# 	var configRecaptchaSendContact = {
# 		recaptchaPublicKey: "6LfbRo8UAAAAACP8o7pnNypM36YmkwpV15Xz2dQr",
# 		recaptchaAction: "sendContact",
# 	};
# </script> <script id="tsa-confirm-title" type="text/microtemplate">
# 	Identity verification
# </script> <script id="tsa-confirm-send-again-pls" type="text/microtemplate">
# 	<div class="modal-inner">
# 		<p>You haven't received it or do not have the phone with you?</p>
# 		<p class="icon-leads"><a href="#" id="sendAgain">Send a new code to the phone</a></p>
# 		<p class="icon-phone">
# 			Contact our team by calling
# 			<a class="phone" href="tel://707 503 310">707 503 310</a>
# 		</p>
# 		<div class="item-form">
# 			<label>
# 				<span>Verification code</span>
# 				<input type="text" id="code_2sa" name="code" data-validation="required" data-message-required="Come on, enter the code ;-)" />
# 			</label>
# 		</div>
# 	</div>
# </script> <script id="tsa-confirm-content" type="text/microtemplate">
# 	<p class="feedback success icon-feedbk-ok">We've sent a code to {{=phone}}</p> <div class="modal-inner"> <p>For your safety, we recommend you check the status of your connection first. To do so, you should see this <span class="nobreak">icon <img src="https://st1.idealista.pt/static/common/release/user-management/resources/img/locker.png"/></span> next to the idealista web address. </p> </div> <div class="modal-inner"> <div class="item-form"> <label> <span>Verification code</span> <input type="text" id="code_2sa" name="code" data-validation="required" data-message-required="Come on, enter the code ;-)"/> </label> <a href="#" id="resendCode">You haven't received it or do not have the phone with you?</a> </div> </div>
# </script> <script id="tsa-confirm-buttons" type="text/microtemplate">
# 	<div class="modal-inner"> <a href="#" title="Confirm and access" class="btn action accept confirm-btn">Confirm and access</a> </div>
# </script> <script id="tsa-confirm-wrong-code-feedback" type="text/microtemplate">
# 	The code you entered doesn't match the one we sent you.
# </script> <script id="tsa-contactus-title" type="text/microtemplate">
# 	Identity verification
# </script> <script id="tsa-contactus-insistent-feedback" type="text/microtemplate">
# 	To continue, call the number that is shown and follow the instructions
# </script> <script id="tsa-contactus-content" type="text/microtemplate">
# 	<p class="feedback error icon-feedbk-ko">It seems that we are having a problem validating the code you are trying to enter</p> <div class="modal-inner"> <div class="contactus"> <p> Contact our team by calling <a class="phone" href="tel://707 503 310">707 503 310</a> and we will provide you with a new verification code </p> </div> </div>
# </script> <script id="tsa-contactus-buttons" type="text/microtemplate">
# 	<div class="modal-inner"> <a href="#" title="Enter new code" class="btn regular accept">Enter new code</a> </div>
# </script> <script id="tsa-contactus-insert-content" type="text/microtemplate">
# 	<div class="modal-inner"> <p>Enter the code we gave you during the call to access your account</p> </div> <div class="modal-inner"> <div class="item-form"> <label> <span>Verification code</span> <input type="text" id="code_2sa" name="code" data-validation="required" data-message-required="Come on, enter the code ;-)"/> </label> </div> </div>
# </script> <script id="tsa-contactus-insert-buttons" type="text/microtemplate">
# 	<div class="modal-inner"> <a href="#" title="Confirm and access" class="btn action accept confirm-btn">Confirm and access</a> </div>
# </script> <script id="blockedemail-modal-title" type="text/microtemplate">
# 	Account blocked
# </script> <script id="blockedemail-modal-content" type="text/microtemplate">
# ...
#
#                         <p>{{=info.address}} {{=info.price}}</p>
#
#
#                         <p>Your reason was:</p>
#
#                         {{info.blockedInfo.offensiveMessages}}
#                             <p>"Offensive messages"</p>
#                         {{/info.blockedInfo.offensiveMessages}}
#
#                         {{info.blockedInfo.seemsFraud}}
#                             <p>"Possible fraud"</p>
#                         {{/info.blockedInfo.seemsFraud}}
#
#                         {{info.blockedInfo.otherReason}}
#                             <p>"<span class="other-reason">{{=info.blockedInfo.text}}</span>"</p>
#                         {{/info.blockedInfo.otherReason}}
#
#                         <p class="blocking-date">Blocked since {{=info.blockedInfo.date}}</p>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#         <div class="modal-footer">
#
#             <button class="btn action">Unblock</button>
#
#             <a href="{{=info.url}}" class="link">See your conversation with <span class='capitalized'>{{=info.userName}}</span></a>
#
#         </div>
#
#     </div>
# </script> <script id="unblock-login-modal-title" type="text/microtemplate">
#
#     Enter idealista
#
# </script> <script id="unblock-login-modal" type="text/microtemplate">
#
#     <div class="modal-inner">
#
#         <p>To contact this advertiser with email address {{=email}}, you must log in to the idealista account associated with it.</p>
#
#         <div class="modal-footer">
#
#             <a class="btn action" href="/en/redirectToLogin">Enter idealista</a>
#
#         </div>
#
#     </div>
# </script> <script id="listing-loading-tmpl" type="text/microtemplate">
# 	<div class="listing-loading"> <div class="listing-loading-content"> <div class="listing-loading-image"> <img src="https://st1.idealista.pt/static/common/release/modules/resources/img/id-spinner2.gif?20201023-1127"> </div> <div class="listing-loading-text"> <p>Searching...</p> </div> </div> </div>
# </script> <script id="custom-slide-end" type="text/microtemplate">
# 	<img class="back-picture"/> <div class="custom-slide" role="article"> <p class="custom-slide-message"> Did you like it? </p> <a class="btn action custom-slide-contact"> Contact </a> <a class="custom-slide-detail action-discard icon-delete" data-role="add"> Discard property </a> </div>
# </script> <script id="save-live-search-error" type="text/microtemplate">
# 	<div id="content"> <div class="feedback warning"> {{@errorMessages}}<span>{{=_val}}<span></br>{{/@errorMessages}} </div> </div> <div id="buttons"> <a href="#" class="btn action cancel">Close</a> <div>
# </script> <script id="expert-card-tpl" type="text/microtemplate">
#     <div class="expert-card card-{{=idx}}" data-commercialdataid="{{=commercialDataId}}">
#         <div class="head">
#             <div class="expert-multimedia">
#                 <div class="image-holder">
#                     {{hasImage}}
#                     <img src="{{=headImageUrl}}" crossorigin="anonymous" />
#                     {{/hasImage}}
#                 </div>
#             </div>
#         </div><div class="info-container">
#             <div class="centrable">
#                 <div class="agency-logo">
#                     <img src="{{=logoUrl}}"/>
#                 </div>
#                 <h4 class="agency-link">
#                     <a class="item-link" href="{{=agencyUrl}}" title="">{{=agencyName}}</a>
#                 </h4>
#             </div>
#
#             <p class="expert-detail stamps">
#                 {{showTMs}}
#                     <span>Member of:</span>
#                     {{@trademarks}}
#                         <img src="{{=_val.url}}" class="stamp" />
#                     {{/@trademarks}}
#                     {{hasLicenseCode}}
#                         <span class="license-code-num">{{=licenseCode}}</span>
#                     {{/hasLicenseCode}}
#                 {{:showTMs}}
#                     &nbsp;
#                 {{/showTMs}}
#             </p>
#
#             <p class="expert-detail">
#                 {{showTotal}}
#                     {{=total}} properties in this area
#                 {{:showTotal}}
#                     &nbsp;
#                 {{/showTotal}}
#             </p>
#
#
#             <p class="expert-detail">
#                 {{showYears}}
#                     {{=years}} years on idealista
#                 {{:showYears}}
#                     &nbsp;
#                 {{/showYears}}
#             </p>
#
#
#             <p class="expert-detail karma karma-{{=karma}}">
#                 <span class="blob score-1"></span><span class="blob score-2"></span><span class="blob score-3"></span><span class="blob score-4"></span><span class="blob score-5"></span>
#             </p>
#
#         </div>
#         <div class="contact-container">
#             <a class="icon-chat js-contact">Free valuation of your property</a>
#         </div>
#     </div>
# </script> <script id="expert-card-compact-tpl" type="text/microtemplate">
#     <div class="expert-card compact card-{{=idx}}" data-commercialdataid="{{=commercialDataId}}">
#         <a class="link-wrap" href="{{=agencyUrl}}" title="{{=agencyName}}">
#         <div class="head">
#             <div class="expert-multimedia">
#                 <div class="image-holder">
#                 </div>
#             </div>
#         </div><div class="info-container">
#             <div class="centrable">
#                 <div class="agency-logo">
#                     <img src="{{=logoUrl}}" crossorigin="anonymous" />
#                 </div>
#                 <h4 class="agency-link">
#                     <a class="item-link" href="{{=agencyUrl}}" title="{{=agencyName}}">{{=agencyName}}</a>
#                 </h4>
#             </div>
#             <div class="details">
#
#             {{showTotal}}
#                 <p class="expert-detail centrable">{{=total}} properties in this area</p>
#             {{/showTotal}}
#
#             {{showYears}}
#                 <p class="expert-detail centrable">{{=years}} years on idealista</p>
#             {{/showYears}}
#             </div>
#         </div>
#         </a>
#     </div>
# </script> <script id="advertiser-info-header-content" type="text/microtemplate">
#
#     {{avatarUrl}}
#         <img src="{{=avatarUrl}}"/>
#     {{/avatarUrl}}
#
#     {{isAdProfessionalAndAgencyIsNotABank}}
#         <div class="advertiser-container">
#             <p class="advertiser-name">
#                 {{showAdvertiserName}}
#                     {{firstName}}
#                         {{=firstName}} {{=lastName}}
#                     {{/firstName}}
#                 {{/showAdvertiserName}}
#             </p>
#         {{:isAdProfessionalAndAgencyIsNotABank}}
#           <div class="advertiser-container">
#             <p class="advertiser-name__costumer">
#                 {{firstName}}
#                     {{isInvoiceAd}}
#                         {{=firstName}}
#                     {{:isInvoiceAd}}
#                         <strong>{{=firstName}}</strong>
#                     {{/isInvoiceAd}}
#                 {{/firstName}}
#             </p>
#         {{/isAdProfessionalAndAgencyIsNotABank}}
#
#         <div class="shortAdDescription">
#             <p class="ellipsis">{{=shortDescription}}</p>
#         </div>
#       </div>
#     </div>
# </script> <script id="advertiser-info-footer-content" type="text/microtemplate">
#
#
#     <div class="advertiser-data">
#
#         {{showPhoneContactMethod}}
#         <div class="{{=contactPhoneClass}}">
#             {{formattedContactPhone1}}
#             <div class="phone first-phone">
#                 <p class="txt-bold _browserPhone icon-phone">
#
#
#
#                             {{=formattedContactPhone1}}
#
#
#                 </p>
#             </div>
#             {{/formattedContactPhone1}}
#
#             {{showFormattedContactPhone2}}
#             <div class="phone last-phone">
#                 <p class="txt-bold _browserPhone icon-phone">
#
#
#
#                             {{=formattedContactPhone2}}
#
#
#                 </p>
#             </div>
#             {{/showFormattedContactPhone2}}
#         </div>
#         {{:showPhoneContactMethod}}
#         <div class="contact-phones">
#             <div class="phone hide-phone">
#                 The advertiser prefers to be contacted only by email.
#             </div>
#         </div>
#         {{/showPhoneContactMethod}}
#
#
#         {{newDevelopmentDirectory}}
#             <div class="new-dev-directory-message">
#                 <div class="new-dev-directory-message">Please have the code {0} ready when calling</div>
#             </div>
#         {{/newDevelopmentDirectory}}
#     </div>
#
#     <div class="module-contact-gray">
#
#         {{agencyIsABank}}
#             <strong>{{=adTypologyName}} repossessed properties</strong>
#             <input type="hidden" name="user-name" value="" />
#             <input type="hidden" name="agency"/>
#         {{:agencyIsABank}}
#             {{isAdProfessional}}
#                 <p class="professional-name">
#                     {{isAdRealEstateDeveloper}}
#                         Developer
#                     {{:isAdRealEstateDeveloper}}
#                         Professional advertiser
#                     {{/isAdRealEstateDeveloper}}
#
#                     {{showProfessionalName}}
#                         {{firstName}}
#                             - {{=firstName}} {{=lastName}}
#                             <input type="hidden" name="user-name" value="{{=firstName}} {{=lastName}}" />
#                         {{:firstName}}
#                             - {{=commercialName}}
#                             <input type="hidden" name="user-name" value="{{=commercialName}}" />
#                         {{/firstName}}
#                     {{:showProfessionalName}}
#                         - {{=commercialName}}
#                         <input type="hidden" name="user-name" value="{{=commercialName}}" />
#                     {{/showProfessionalName}}
#                 </p>
#                 <input type="hidden" name="professional"/>
#                 {{:isAdProfessional}}
#
#                     <span class="icon-block"></span>
#
#                 <p class="txt-ref">
#                     {{firstName}}
#                         {{isInvoiceAd}}
#                             <!-- Si, es feo, Se hace de esta forma ya que si no devuelve un "undefined" con {{!isInvoiceAd}}...  -->
#                         {{:isInvoiceAd}}
#                             Private owner -
#                         {{/isInvoiceAd}}
#                         {{=firstName}}
#                         <input type="hidden" name="user-name" value="{{=firstName}} {{=lastName}}" />
#                     {{/firstName}}
#                 </p>
#             {{/isAdProfessional}}
#         {{/agencyIsABank}}
#
#         <p>
#             {{=referenceMessage}}
#         </p>
#
#
#         {{showAboutAdvertiser}}
#             <div class="advertiser-name-container">
#                 {{isVirtualMicrosite}}
#                     <p class="about-advertiser-name" >
#                         {{=commercialNamePhraseBlock}}
#                     </p>
#                 {{:isVirtualMicrosite}}
#                     <a class="about-advertiser-name" href="{{=advertiserNameLink}}" title="{{=commercialNamePhraseBlock}}">
#                         {{=commercialNamePhraseBlock}}
#                     </a>
#                 {{/isVirtualMicrosite}}
#
#                 <p class="advertiser-name-location">{{=micrositeCityName}}</p>
#             </div>
#
#
#             <div class="about-advertiser">
#                 {{mustShowLogo}}
#                 <div class="advertiser-logo">
#                     <a href="{{=advertiserNameLink}}">
#                         <img src="{{=advertiserLogoUrl}}"
#                              data-ondemand-img="{{=advertiserLogoUrl}}"
#                              width="125"
#                              height="60"
#                              alt="{{=commercialNamePhraseBlock}}" />
#                     </a>
#                 </div>
#                 {{/mustShowLogo}}
#             </div>
#         {{/showAboutAdvertiser}}
#     </div>
# </script> <script id="typology_1" type="text/microtemplate">
#         Hi, I’m interested in this flat and would like to arrange a viewing.
# Regards
# </script> <script id="typology_2" type="text/microtemplate">
#     Hi, I’m interested in this property and would like to arrange a viewing.
# Regards
# </script> <script id="typology_3" type="text/microtemplate">
#     Hi, I’m interested in this property and would like to arrange a viewing.
# Regards
# </script> <script id="typology_4" type="text/microtemplate">
#     Hi, I’m interested in this garage and would like to arrange a viewing.
# Regards
# </script> <script id="typology_5" type="text/microtemplate">
#     Hi, I’m interested in this office and would like to arrange a viewing.
# Regards
# </script> <script id="typology_6" type="text/microtemplate">
#     Hi, I’m interested in this property and would like to arrange a viewing.
# Regards
# </script> <script id="typology_7" type="text/microtemplate">
#     Hi, I’m interested in this room and would like to arrange a viewing.
# Regards
# </script> <script id="typology_8" type="text/microtemplate">
#     Hi, I’m interested in this land and would like to arrange a viewing.
# Regards
# </script> <script id="typology_10" type="text/microtemplate">
#     Hi, I’m interested in this new housing development and would like to arrange a viewing.
# Kind regards
# </script> <script id="typology_12" type="text/microtemplate">
#     Hi, I’m interested in this storage room and would like to arrange a viewing.
# Regards
# </script> <script id="typology_13" type="text/microtemplate">
#     Hi, I’m interested in this building and would like to arrange a viewing.
# Regards
# </script> <script async="" src="https://st1.idealista.pt/static/common/js/criteo/ld.js?20201023-1127" type="text/javascript"></script>
# <div id="criteo-tags-div" style="display: none;"><iframe frameborder="0" height="0" id="criteo-syncframe" src='https://gum.criteo.com/syncframe?topUrl=www.idealista.pt#{"idfs":{"origin":0,"value":null},"lwid":{"origin":3,"value":"8c29f843-7873-4074-80af-d61e8ac1e493"},"optout":{"origin":0,"value":null},"origin":"onetag","sid":{"origin":0,"value":null},"tld":"idealista.pt","topUrl":"www.idealista.pt","uid":null,"version":"5_1_1"}' style="border-width:0px; margin:0px; display:none" title="Criteo GUM iframe" width="0"></iframe></div><div><div class="grecaptcha-badge" data-style="bottomright" style="width: 256px; height: 60px; position: fixed; visibility: hidden; display: block; transition: right 0.3s ease 0s; bottom: 14px; right: -186px; box-shadow: gray 0px 0px 5px; border-radius: 2px; overflow: hidden;"><div class="grecaptcha-logo"><iframe frameborder="0" height="60" name="a-rjejpd5bewr6" role="presentation" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox allow-storage-access-by-user-activation" scrolling="no" src="https://www.google.com/recaptcha/api2/anchor?ar=1&amp;k=6LfbRo8UAAAAACP8o7pnNypM36YmkwpV15Xz2dQr&amp;co=aHR0cHM6Ly93d3cuaWRlYWxpc3RhLnB0OjQ0Mw..&amp;hl=en&amp;v=T9w1ROdplctW2nVKvNJYXH8o&amp;size=invisible&amp;cb=gygfsltwuim7" width="256"></iframe></div><div class="grecaptcha-error"></div><textarea class="g-recaptcha-response" id="g-recaptcha-response-100000" name="g-recaptcha-response" style="width: 250px; height: 40px; border: 1px solid rgb(193, 193, 193); margin: 10px 25px; padding: 0px; resize: none; display: none;"></textarea></div><iframe style="display: none;"></iframe></div><iframe frameborder="0" height="0" scrolling="no" src="https://secure-assets.rubiconproject.com/utils/xapi/multi-sync.html?p=smartadserver&amp;endpoint=eu" style="margin: 0px; padding: 0px; display: none; width: 0px; height: 0px; visibility: hidden;" width="0"></iframe><iframe height="0" style="display: none;" title="Criteo DIS iframe" width="0"></iframe></body></html>>
